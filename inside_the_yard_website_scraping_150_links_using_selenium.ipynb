# %%
# importing webdriver from selenium
from selenium import webdriver
from webdriver_manager.chrome import ChromeDriverManager
from selenium.webdriver.common.by import By


driver = webdriver.Chrome(ChromeDriverManager().install())

# URL of website
url = "https://www.insidetheyard.com/"

# Opening the website
driver.get(url)

# Getting current URL source code
get_links=driver.find_elements(By.TAG_NAME, "a")

get_title = driver.title

# Printing the title of this URL
print(get_title)
# Out:
# [WDM] - Downloading: 100%|█████████████████████████████████████████████████████████| 6.46M/6.46M [00:10<00:00, 664kB/s]
# C:\Users\ahsan\AppData\Local\Temp/ipykernel_14364/1762000981.py:7: DeprecationWarning: executable_path has been deprecated, please pass in a Service object
#   driver = webdriver.Chrome(ChromeDriverManager().install())
# Solve Python | HackerRank

# %%
a=[]
b=[]  
for i in range(58):
    url="https://www.insidetheyard.com/page/{}".format(i)
    driver.get(url)
    get_links=driver.find_elements(By.TAG_NAME, "a")
    for i in get_links:
        a.append(i.text)
        b.append(i.get_attribute("href"))
    lms
    
print(a,b)
# Out:
# ['Skip to content', '', 'Lawn Care', '', '', '', 'Gardening', '', '', '', 'Insect Guider', '', '', '', 'Tools & Diagrams', '', '', '', '', 'Ask Our Support!', '', '', 'GARDENING', 'FACTS & PROBLEMS', 'How Many Lavender Seeds Per Pot You Should Plant?', 'Myler David', 'READ MORE\nHOW MANY LAVENDER SEEDS PER POT YOU SHOULD PLANT?', '', 'LAWN CARE', 'FACTS & PROBLEMS', 'Is Lawncare One Word? A Great Debate, But What’s Experts Say?', 'White S Mike', 'READ MORE\nIS LAWNCARE ONE WORD? A GREAT DEBATE, BUT WHAT’S EXPERTS SAY?', '', 'LAWN CARE', 'FACTS & PROBLEMS', 'Bosch Pressure Washer Keeps Cutting Out- Here’s The Solutions You Are Looking For!', 'Mark Jaoson', 'READ MORE\nBOSCH PRESSURE WASHER KEEPS CUTTING OUT- HERE’S THE SOLUTIONS YOU ARE LOOKING FOR!', '', 'LAWN CARE', 'FACTS & PROBLEMS', 'GreenWorks Pressure Washer Gun Leaking Troubleshooting- Reasons and Solutions', 'Mark Jaoson', 'READ MORE\nGREENWORKS PRESSURE WASHER GUN LEAKING TROUBLESHOOTING- REASONS AND SOLUTIONS', '', 'CHARTS'
# ...

# %%
print(a)
# Out:
# ['Skip to content', '', 'Lawn Care', '', '', '', 'Gardening', '', '', '', 'Insect Guider', '', '', '', 'Tools & Diagrams', '', '', '', '', 'Ask Our Support!', '', '', 'GARDENING', 'FACTS & PROBLEMS', 'How Many Lavender Seeds Per Pot You Should Plant?', 'Myler David', 'READ MORE\nHOW MANY LAVENDER SEEDS PER POT YOU SHOULD PLANT?', '', 'LAWN CARE', 'FACTS & PROBLEMS', 'Is Lawncare One Word? A Great Debate, But What’s Experts Say?', 'White S Mike', 'READ MORE\nIS LAWNCARE ONE WORD? A GREAT DEBATE, BUT WHAT’S EXPERTS SAY?', '', 'LAWN CARE', 'FACTS & PROBLEMS', 'Bosch Pressure Washer Keeps Cutting Out- Here’s The Solutions You Are Looking For!', 'Mark Jaoson', 'READ MORE\nBOSCH PRESSURE WASHER KEEPS CUTTING OUT- HERE’S THE SOLUTIONS YOU ARE LOOKING FOR!', '', 'LAWN CARE', 'FACTS & PROBLEMS', 'GreenWorks Pressure Washer Gun Leaking Troubleshooting- Reasons and Solutions', 'Mark Jaoson', 'READ MORE\nGREENWORKS PRESSURE WASHER GUN LEAKING TROUBLESHOOTING- REASONS AND SOLUTIONS', '', 'CHARTS'
# ...

# %%
n1=[]
m1=[]
for lnk in get_links:
    n1.append(lnk.get_attribute("href"))
    m1.append(lnk.text)
print(n1,m1)
# Out:
# ['https://www.insidetheyard.com/#main', 'https://www.insidetheyard.com/', 'https://www.insidetheyard.com/category/lawn-care/', 'https://www.insidetheyard.com/category/lawn-care/how-to/', 'https://www.insidetheyard.com/category/lawn-care/facts-and-problems/', 'https://www.insidetheyard.com/category/lawn-care/reviews-and-comparison/', 'https://www.insidetheyard.com/category/gardening/', 'https://www.insidetheyard.com/category/gardening/how-to-gardening/', 'https://www.insidetheyard.com/category/gardening/facts-and-problems-gardening/', 'https://www.insidetheyard.com/category/gardening/reviews-and-comparison-gardening/', 'https://www.insidetheyard.com/category/insect-guider/', 'https://www.insidetheyard.com/category/insect-guider/how-to-insect-guider/', 'https://www.insidetheyard.com/category/insect-guider/facts-and-problems-insect-guider/', 'https://www.insidetheyard.com/category/insect-guider/pest-controlling/', 'https://www.insidetheyard.com/category/tools-and-diagrams/', 'https://ww
# ...

# %%
import pandas as pd
df=pd.DataFrame({"Name":a,"Links":b})

# %%
df
# Out:
#                  Name                                              Links
# 0     Skip to content         https://www.insidetheyard.com/page/0/#main
# 1                                         https://www.insidetheyard.com/
# 2           Lawn Care  https://www.insidetheyard.com/category/lawn-care/
# 3                      https://www.insidetheyard.com/category/lawn-ca...
# 4                      https://www.insidetheyard.com/category/lawn-ca...
# ...               ...                                                ...
# 6323                   https://www.insidetheyard.com/category/tools-a...
# 6324                   https://www.insidetheyard.com/category/tools-a...
# 6325                   https://www.insidetheyard.com/category/tools-a...
# 6326                   https://www.insidetheyard.com/peat-moss-calcul...
# 6327                   https://www.insidetheyard.com/prodiamine-calcu...
#
# [6328 rows x 2 columns]

# %%
df.to_csv("{}_links.csv".format(get_title))

# %%
df.to_excel("{}_links.xlsx".format(get_title))

# %%
from selenium import webdriver
import time
from webdriver_manager.chrome import ChromeDriverManager

browser = webdriver.Chrome(ChromeDriverManager().install())

browser.get("https://www.kaggle.com/rankings?group=notebooks")
total_height = int(browser.execute_script("return document.body.scrollHeight"))

for i in range(1, total_height, 5):
    browser.execute_script("window.scrollTo(0, {});".format(i))
# Out:
# C:\Users\ahsan\AppData\Local\Temp/ipykernel_8384/1222643653.py:5: DeprecationWarning: executable_path has been deprecated, please pass in a Service object
#   browser = webdriver.Chrome(ChromeDriverManager().install())

# %%
import pandas as pd
ah=pd.read_csv("ahsan.csv")

# %%
ah
# Out:
#       Unnamed: 0             Name  \
# 0              0  Skip to content
# 1              1              NaN
# 2              2        Lawn Care
# 3              3              NaN
# 4              4              NaN
# ...          ...              ...
# 6323        6323              NaN
# 6324        6324              NaN
# 6325        6325              NaN
# 6326        6326              NaN
# 6327        6327              NaN
#
#                                                   Links
# 0            https://www.insidetheyard.com/page/0/#main
# 1                        https://www.insidetheyard.com/
# 2     https://www.insidetheyard.com/category/lawn-care/
# 3     https://www.insidetheyard.com/category/lawn-ca...
# 4     https://www.insidetheyard.com/category/lawn-ca...
# ...                                                 ...
# 6323  https://www.insidetheyard.com/category/tools-a...
# 6324  https://www.insidetheyard.com/category/tools-a...
# ...
